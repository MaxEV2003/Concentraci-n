# %% [markdown]
# <a href="https://colab.research.google.com/github/MaxEV2003/Extracci-n-de-datos-Concentraci-n/blob/main/1_Extraccion_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos librerias requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Cargar archivos csv o xlsx desde equipo
from google.colab import files
files.upload()

# %%
#Cargar desde un archiuvo .xlsx sin indice
df = pd.read_excel('Antigüedad de saldos 17.03.2023.xlsx')
df

# %%
#Verficamos informacion del DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 164 entries, 0 to 163
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   No. CLIENTE        162 non-null    object
#  1   NOMBRE             163 non-null    object
#  2   FACTURA            163 non-null    object
#  3   FECHA_FACTURA      163 non-null    datetime64[ns]
#  4   FECHA_VENCIMIENTO  164 non-null    datetime64[ns]
#  5   MONTO ADEUDADO     163 non-null    float64
# dtypes: datetime64[ns](2), float64(1), object(3)
# memory usage: 7.8+ KB

# %%
#Imprimo los primeros 5 registros del dataframe
df.head()
# Out:
#   No. CLIENTE                                        NOMBRE FACTURA  \
# 0        6401                          DONGA HWASUNG MEXICO  F40238
# 1        6401                          DONGA HWASUNG MEXICO  F40353
# 2        4598  PROVEEDORA DE SEGURIDAD INDUSTRIAL DEL GOLFO  F40352
# 3        3930                          INDUSTRIAS LANCERMEX  F40217
# 4        4712                                        HELVEX  F40173
#
#   FECHA_FACTURA FECHA_VENCIMIENTO  MONTO ADEUDADO
# 0    2023-02-24        2023-03-26        97485.94
# 1    2023-03-14        2023-04-13        97485.94
# 2    2023-03-14        2023-04-13        64916.21
# 3    2023-02-23        2023-03-25        52715.74
# 4    2023-02-17        2023-04-03        50639.80

# %% [markdown]
# ##Filtros basicos para variables cualitativas

# %%
#Filtro por objeto
filtro1 = df[df["NOMBRE"] == "INDUSTRIAS LANCERMEX"]
filtro1
# Out:
#    No. CLIENTE                NOMBRE FACTURA FECHA_FACTURA FECHA_VENCIMIENTO  \
# 3         3930  INDUSTRIAS LANCERMEX  F40217    2023-02-23        2023-03-25
# 12        3930  INDUSTRIAS LANCERMEX  F40114    2023-02-09        2023-03-11
#
#     MONTO ADEUDADO
# 3         52715.74
# 12        35143.82

# %%
#Filtro por filas
#filtro2= df.iloc[1:50: ]               #Filas consecutivas
filtro2 = df.iloc[ [8, 24, 100] , : ]   #Filas no consecutivas
filtro2
# Out:
#     No. CLIENTE                  NOMBRE FACTURA FECHA_FACTURA  \
# 8           644   CLAVOS NACIONALES C.N  F40340    2023-03-13
# 24         8708       TE.MEX AUTOMOTIVE  F40183    2023-02-20
# 100        3926  PRODUCTOS PENNSYLVANIA  F40357    2023-03-14
#
#     FECHA_VENCIMIENTO  MONTO ADEUDADO
# 8          2023-05-12        45216.34
# 24         2023-03-13        22956.40
# 100        2023-04-13         2756.16

# %%
#Filtro por columnas
#filtro3 = df.iloc[ : , 1:3]         #Columas consecutivas
filtro3 = df.iloc[ 10:20 , [1,4,5]]  #Columas no consecutivas
filtro3
# Out:
#                                           NOMBRE FECHA_VENCIMIENTO  \
# 10                                      RICHALUM        2023-03-14
# 11  TRANSPORTADORES Y FABRICACIONES INDUSTRIALES        2023-03-12
# 12                          INDUSTRIAS LANCERMEX        2023-03-11
# 13  PROVEEDORA DE SEGURIDAD INDUSTRIAL DEL GOLFO        2023-03-19
# 14                AUTOLIV STEERING WHEELS MEXICO        2023-03-06
# 15                                       PQUISEM        2023-03-10
# 16                               SIEGFRIED RHEIN        2023-02-27
# 17                               SIEGFRIED RHEIN        2023-03-04
# 18                            MOLINERA DE MEXICO        2023-03-29
# 19                             Q SEALS DE MEXICO        2023-05-12
#
#     MONTO ADEUDADO
# 10        42880.05
# 11        37588.59
# 12        35143.82
# 13        34493.76
# 14        32886.00
# 15        30880.31
# 16        30276.00
# 17        30276.00
# 18        29642.92
# 19        29562.60

# %%
df1 = pd.read_excel('Antigüedad de saldos 17.03.2023.xlsx', index_col=1)
df1
# Out:
#                                                    No. CLIENTE  FACTURA  \
# NOMBRE
# DONGA HWASUNG MEXICO                                      6401   F40238
# DONGA HWASUNG MEXICO                                      6401   F40353
# PROVEEDORA DE SEGURIDAD INDUSTRIAL DEL GOLFO              4598   F40352
# INDUSTRIAS LANCERMEX                                      3930   F40217
# HELVEX                                                    4712   F40173
# ...                                                        ...      ...
# CENTRO DE INVESTIGACION Y DE ESTUDIOS AVANZADOS...         856   F40055
# PÚBLICO EN GENERAL                                        5926  NV00777
# PÚBLICO EN GENERAL                                        5926  NV00778
# PÚBLICO EN GENERAL                                        5926  NV00779
# FISHERS QUERETARO                                         8429   F38248
#
#                                                    FECHA_FACTURA  \
# NOMBRE
# ...

# %%
#Paso 2: Aplicamos Filtro de filas vs columnas
filtro4=df1.loc[["HELVEX", "DONGA HWASUNG MEXICO"], ["MONTO ADEUDADO"]]
filtro4
# Out:
#                       MONTO ADEUDADO
# NOMBRE
# HELVEX                      50639.80
# DONGA HWASUNG MEXICO        97485.94
# DONGA HWASUNG MEXICO        97485.94
# DONGA HWASUNG MEXICO        10759.00
# DONGA HWASUNG MEXICO         9396.00

# %%
#Filtro por cabecera
filtro5=df.tail()
filtro5
# Out:
#                                                    No. CLIENTE  FACTURA  \
# NOMBRE
# CENTRO DE INVESTIGACION Y DE ESTUDIOS AVANZADOS...         856   F40055
# PÚBLICO EN GENERAL                                        5926  NV00777
# PÚBLICO EN GENERAL                                        5926  NV00778
# PÚBLICO EN GENERAL                                        5926  NV00779
# FISHERS QUERETARO                                         8429   F38248
#
#                                                    FECHA_FACTURA  \
# NOMBRE
# CENTRO DE INVESTIGACION Y DE ESTUDIOS AVANZADOS...    2023-01-31
# PÚBLICO EN GENERAL                                    2023-03-07
# PÚBLICO EN GENERAL                                    2023-03-09
# PÚBLICO EN GENERAL                                    2023-03-09
# FISHERS QUERETARO                                     2022-05-27
#
#                                                    FECHA_VENCIMIENTO  \
# NOMBRE
# ...

# %%
#Filtro por comparacion
filtro6 = df[df["MONTO ADEUDADO"] > 70000]
filtro6
# Out:
#                      No. CLIENTE FACTURA FECHA_FACTURA FECHA_VENCIMIENTO  \
# NOMBRE
# DONGA HWASUNG MEXICO        6401  F40238    2023-02-24        2023-03-26
# DONGA HWASUNG MEXICO        6401  F40353    2023-03-14        2023-04-13
#
#                       MONTO ADEUDADO
# NOMBRE
# DONGA HWASUNG MEXICO        97485.94
# DONGA HWASUNG MEXICO        97485.94

# %%
#Filtro Y
filtro7 = df[(df["MONTO ADEUDADO"] < 6000) & (df["FECHA_FACTURA"] == "2023-03-14")]
filtro7
# Out:
#                                                    No. CLIENTE FACTURA  \
# NOMBRE
# CONSTRUCCIONES ELECTROMECANICAS Y SERVICIOS IND...         409  F40359
# PRODUCTOS PENNSYLVANIA                                    3926  F40358
# PRODUCTOS PENNSYLVANIA                                    3926  F40357
# PÚBLICO EN GENERAL                                        5926  F40362
# FRESCOPACK                                                2216  F40355
# TERMOFORMADOS                                             1284  F40349
# GABRIELA GARCIA SANCHEZ                                   8872  F40360
# UCH COMERCIAL                                             8228  F40365
#
#                                                    FECHA_FACTURA  \
# NOMBRE
# CONSTRUCCIONES ELECTROMECANICAS Y SERVICIOS IND...    2023-03-14
# PRODUCTOS PENNSYLVANIA                                2023-03-14
# PRODUCTOS PENNSYLVANIA                                2023-03-14
# ...

# %%
#Filtro o
filtro8 = df[(df['MONTO ADEUDADO'] < 6000) | (df['FECHA_FACTURA'] == "2023-03-14")]
filtro8
# Out:
#                                                    No. CLIENTE  FACTURA  \
# NOMBRE
# DONGA HWASUNG MEXICO                                      6401   F40353
# PROVEEDORA DE SEGURIDAD INDUSTRIAL DEL GOLFO              4598   F40352
# CLAVOS NACIONALES C.N                                      644   F40351
# RICHALUM                                                  3937   F40361
# COVEMEX                                                    417   F40354
# ...                                                        ...      ...
# CENTRO DE INVESTIGACION Y DE ESTUDIOS AVANZADOS...         856   F40055
# PÚBLICO EN GENERAL                                        5926  NV00777
# PÚBLICO EN GENERAL                                        5926  NV00778
# PÚBLICO EN GENERAL                                        5926  NV00779
# FISHERS QUERETARO                                         8429   F38248
#
#                                                    FECHA_FACTURA  \
# NOMBRE
# ...

# %%
#Filtro not
filtro9 = df[~(df['FECHA_FACTURA'] == "2023-03-14")]
filtro9
# Out:
#                                                    No. CLIENTE  FACTURA  \
# NOMBRE
# DONGA HWASUNG MEXICO                                      6401   F40238
# INDUSTRIAS LANCERMEX                                      3930   F40217
# HELVEX                                                    4712   F40173
# AUTOLIV STEERING WHEELS MEXICO                            1429   F39979
# AUTOLIV STEERING WHEELS MEXICO                            1429   F40319
# ...                                                        ...      ...
# CENTRO DE INVESTIGACION Y DE ESTUDIOS AVANZADOS...         856   F40055
# PÚBLICO EN GENERAL                                        5926  NV00777
# PÚBLICO EN GENERAL                                        5926  NV00778
# PÚBLICO EN GENERAL                                        5926  NV00779
# FISHERS QUERETARO                                         8429   F38248
#
#                                                    FECHA_FACTURA  \
# NOMBRE
# ...

# %%
#Convertir archivo filtrado a CSV
filtro9.to_csv("Entregable1.csv")

# %%
#Descargar archivo filtrado en csv
from google.colab import files

files.download("Entregable1.csv")
