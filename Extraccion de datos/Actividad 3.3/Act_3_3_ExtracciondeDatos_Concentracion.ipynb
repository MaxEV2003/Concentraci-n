# %% [markdown]
# <a href="https://colab.research.google.com/github/MaxEV2003/Concentraci-n/blob/main/Extraccion%20de%20datos/Actividad%203.3/Act_3_3_ExtracciondeDatos_Concentracion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Utilizar el nuevo repositorio con el nombre: Actividad 1
#
# Agregar el archivo: Inmuebles.xlsx
#
# Aplicar los siguientes filtros:

# %% [markdown]
# **a) Eliminar la fila “0” de “Unnamed” y Eliminar la columna “0” y la columna “Referencia”**

# %%
df= pd.read_excel('Inmuebles.xlsx',skiprows=1)

# %%
df.head()
# Out:
#    Referencia Fecha_Alta     Tipo Operación  Provincia  Superficie  \
# 0           1 2004-01-01  Parking  Alquiler     Lleida       291.0
# 1           2 2004-01-01    Local     Venta     Girona       185.0
# 2           3 2004-01-01  Oficina  Alquiler     Girona        82.0
# 3           4 2004-01-02  Parking  Alquiler     Girona       285.0
# 4           5 2004-01-02    Suelo     Venta  Tarragona       152.0
#
#    Precio Venta Fecha Venta Vendedor
# 0     2133903.0  2004-06-19   Carmen
# 1     1945424.0  2004-04-19    Pedro
# 2           NaN  2004-11-08  Joaquín
# 3           NaN  2004-04-27    Jesús
# 4      185000.0  2004-07-10    María

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3337 entries, 0 to 3336
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Referencia    3337 non-null   int64
#  1   Fecha_Alta    3337 non-null   datetime64[ns]
#  2   Tipo          3337 non-null   object
#  3   Operación     3337 non-null   object
#  4   Provincia     3337 non-null   object
#  5   Superficie    3335 non-null   float64
#  6   Precio Venta  3335 non-null   float64
#  7   Fecha Venta   2759 non-null   datetime64[ns]
#  8   Vendedor      2759 non-null   object
# dtypes: datetime64[ns](2), float64(2), int64(1), object(4)
# memory usage: 234.8+ KB

# %%
filtroa=df.drop('Referencia',axis=1).head()
filtroa.head()
# Out:
#   Fecha_Alta     Tipo Operación  Provincia  Superficie  Precio Venta  \
# 0 2004-01-01  Parking  Alquiler     Lleida       291.0     2133903.0
# 1 2004-01-01    Local     Venta     Girona       185.0     1945424.0
# 2 2004-01-01  Oficina  Alquiler     Girona        82.0           NaN
# 3 2004-01-02  Parking  Alquiler     Girona       285.0           NaN
# 4 2004-01-02    Suelo     Venta  Tarragona       152.0      185000.0
#
#   Fecha Venta Vendedor
# 0  2004-06-19   Carmen
# 1  2004-04-19    Pedro
# 2  2004-11-08  Joaquín
# 3  2004-04-27    Jesús
# 4  2004-07-10    María

# %%
filtroa.to_csv('Filtro_A.csv')

# %% [markdown]
# b) Todos las registros de “Fecha Alta : igual a 2007-04-29 00:00:00 y a 2004-01-02 00:00:00

# %%
filtrob=df[(df['Fecha_Alta']=='2004-01-02')|(df['Fecha_Alta']=='2007-04-29')]
filtrob.head()
# Out:
#       Referencia Fecha_Alta        Tipo Operación  Provincia  Superficie  \
# 3              4 2004-01-02     Parking  Alquiler     Girona       285.0
# 4              5 2004-01-02       Suelo     Venta  Tarragona       152.0
# 3331        3332 2007-04-29     Oficina     Venta     Lleida       190.0
# 3332        3333 2007-04-29  Industrial  Alquiler     Lleida       221.0
# 3333        3334 2007-04-29        Piso  Alquiler     Girona        55.0
#
#       Precio Venta Fecha Venta Vendedor
# 3              NaN  2004-04-27    Jesús
# 4         185000.0  2004-07-10    María
# 3331     1031320.0         NaT      NaN
# 3332     1450644.0         NaT      NaN
# 3333      454080.0         NaT      NaN

# %%
filtrob.to_csv('Filtro_B.csv')

# %% [markdown]
# c) Todos los registros de “ Tipo: parking, local, industrial y piso”

# %%
filtroc=df[(df['Tipo']=='Parking')|(df['Tipo']=='Local')|(df['Tipo']=='Industrial')|(df['Tipo']=='Piso')]
filtroc.head()
# Out:
#    Referencia Fecha_Alta        Tipo Operación  Provincia  Superficie  \
# 0           1 2004-01-01     Parking  Alquiler     Lleida       291.0
# 1           2 2004-01-01       Local     Venta     Girona       185.0
# 3           4 2004-01-02     Parking  Alquiler     Girona       285.0
# 5           6 2004-01-03  Industrial  Alquiler     Girona       131.0
# 6           7 2004-01-03     Parking  Alquiler  Tarragona         NaN
#
#    Precio Venta Fecha Venta Vendedor
# 0     2133903.0  2004-06-19   Carmen
# 1     1945424.0  2004-04-19    Pedro
# 3           NaN  2004-04-27    Jesús
# 5      953156.0  2004-09-05    Pedro
# 6      406686.0  2004-06-07    Pedro

# %%
filtroc.to_csv('Filtro_C.csv')

# %% [markdown]
# d) Todos los registros con “Provincia” igual a “Girona” y con “Superficie” mayor a “100”

# %%
filtrod = df[(df['Provincia'] == 'Girona') & (df['Superficie'] > 100)]
filtrod.head()
# Out:
#     Referencia Fecha_Alta        Tipo Operación Provincia  Superficie  \
# 1            2 2004-01-01       Local     Venta    Girona       185.0
# 3            4 2004-01-02     Parking  Alquiler    Girona       285.0
# 5            6 2004-01-03  Industrial  Alquiler    Girona       131.0
# 7            8 2004-01-03     Oficina     Venta    Girona       235.0
# 10          11 2004-01-04     Oficina  Alquiler    Girona       124.0
#
#     Precio Venta Fecha Venta Vendedor
# 1      1945424.0  2004-04-19    Pedro
# 3            NaN  2004-04-27    Jesús
# 5       953156.0  2004-09-05    Pedro
# 7      2158475.0  2004-10-31    Jesús
# 10      627068.0  2004-10-28    Pedro

# %%
filtrod.to_csv('Filtro_D.csv')

# %% [markdown]
# e) Todos los registros con “Precio Venta: mayor a 1000,000” o “vendedor” igual a “Carmen o Joaquin”

# %%
filtroe = df[(df['Precio Venta'] > 1_000_000) | (df['Vendedor']=='Carmen')|(df['Vendedor']=='Joaquin')]
filtroe.head()
# Out:
#    Referencia Fecha_Alta     Tipo Operación Provincia  Superficie  \
# 0           1 2004-01-01  Parking  Alquiler    Lleida       291.0
# 1           2 2004-01-01    Local     Venta    Girona       185.0
# 7           8 2004-01-03  Oficina     Venta    Girona       235.0
# 8           9 2004-01-04     Piso  Alquiler    Lleida       108.0
# 9          10 2004-01-04  Parking     Venta    Lleida       299.0
#
#    Precio Venta Fecha Venta Vendedor
# 0     2133903.0  2004-06-19   Carmen
# 1     1945424.0  2004-04-19    Pedro
# 7     2158475.0  2004-10-31    Jesús
# 8     1024380.0  2004-12-28    Jesús
# 9     2042768.0  2004-10-06  Joaquín

# %%
filtroe.to_csv('Filtro_E.csv')

# %% [markdown]
# f) Todos los registros que no sean de “Provincia : Barcelona“

# %%
filtrof = df[(df['Provincia'] != 'Barcelona')]
filtrof.head()
# Out:
#    Referencia Fecha_Alta     Tipo Operación  Provincia  Superficie  \
# 0           1 2004-01-01  Parking  Alquiler     Lleida       291.0
# 1           2 2004-01-01    Local     Venta     Girona       185.0
# 2           3 2004-01-01  Oficina  Alquiler     Girona        82.0
# 3           4 2004-01-02  Parking  Alquiler     Girona       285.0
# 4           5 2004-01-02    Suelo     Venta  Tarragona       152.0
#
#    Precio Venta Fecha Venta Vendedor
# 0     2133903.0  2004-06-19   Carmen
# 1     1945424.0  2004-04-19    Pedro
# 2           NaN  2004-11-08  Joaquín
# 3           NaN  2004-04-27    Jesús
# 4      185000.0  2004-07-10    María

# %%
filtrof.to_csv('Filtro_F.csv')

# %% [markdown]
# g)Todos los registros que no sean de “Operación: alquiler “ ni “Tipo: oficina“

# %%
filtrog = df[(df['Operación'] != 'Alquiler')&(df['Tipo'] != 'Oficina')]
filtrog.head()
# Out:
#     Referencia Fecha_Alta        Tipo Operación  Provincia  Superficie  \
# 1            2 2004-01-01       Local     Venta     Girona       185.0
# 4            5 2004-01-02       Suelo     Venta  Tarragona       152.0
# 9           10 2004-01-04     Parking     Venta     Lleida       299.0
# 11          12 2004-01-04  Industrial     Venta     Girona       187.0
# 12          13 2004-01-04     Parking     Venta  Barcelona         NaN
#
#     Precio Venta Fecha Venta Vendedor
# 1      1945424.0  2004-04-19    Pedro
# 4       185000.0  2004-07-10    María
# 9      2042768.0  2004-10-06  Joaquín
# 11      999328.0  2004-04-05   Carmen
# 12     2937300.0  2004-11-04    Jesús

# %%
filtrog.to_csv('Filtro_G.csv')

# %%
from google.colab import files
files.download('Filtro_G.csv')
